# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Pilot_List.xlsx')
# Out:
# /workspaces/Caltrans-Web-Automation-Testing/.venv/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#    District  Division/Office  \
# 0       D02              NaN
# 1       D02              NaN
# 2       D02              NaN
# 3       D02              NaN
# 4       D02              NaN
# ..      ...              ...
# 63      D11              NaN
# 64      D11              NaN
# 65      D11              NaN
# 66      D11              NaN
# 67      D11              NaN
#
#                                         Project Title  \
# 0                           Rural Winter Travel Times
# 1   Connected Vehicle Highway Grip Factor Reportin...
# 2                        Starlink Satellite Broadband
# 3           Acoustical Optical Fiber Detection System
# 4                                 Tethered UAV System
# ..                                                ...
# 63  Integrating the Wrong Way Detection System int...
# 64                 Imperial County ITS Implementation
# 65               San Vicente Corridor ITS Deployments
# 66       V2X Applications at Signalized Intersections
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   District                     68 non-null     object
#  1   Division/Office              0 non-null      float64
#  2   Project Title                68 non-null     object
#  3   Project Description (Brief)  67 non-null     object
#  4   Project Location             34 non-null     object
#  5   Status                       68 non-null     object
#  6   Project Estimate             0 non-null      float64
#  7   Funding available            0 non-null      float64
#  8   Project point-of-contact     65 non-null     object
#  9   Project Category             67 non-null     object
#  10  Comment                      22 non-null     object
# dtypes: float64(3), object(8)
# memory usage: 6.0+ KB

# %% [markdown]
# # Drop columns that have 0 content

# %%
df_copy = df.drop(columns=["Division/Office","Project Estimate", "Funding available"])

# %% [markdown]
# # Some locations are present, some are not

# %%
df_copy
# Out:
#    District                                      Project Title  \
# 0       D02                          Rural Winter Travel Times
# 1       D02  Connected Vehicle Highway Grip Factor Reportin...
# 2       D02                       Starlink Satellite Broadband
# 3       D02          Acoustical Optical Fiber Detection System
# 4       D02                                Tethered UAV System
# ..      ...                                                ...
# 63      D11  Integrating the Wrong Way Detection System int...
# 64      D11                 Imperial County ITS Implementation
# 65      D11               San Vicente Corridor ITS Deployments
# 66      D11       V2X Applications at Signalized Intersections
# 67      D11                             Adaptive ramp metering
#
#                           Project Description (Brief) Project Location  \
# 0   Develop chain-on area winter travel time delay...              NaN
# ...

# %% [markdown]
# # Replace NaN with N/A as string

# %%
df_copy.fillna("N/A")
# Out:
#    District                                      Project Title  \
# 0       D02                          Rural Winter Travel Times
# 1       D02  Connected Vehicle Highway Grip Factor Reportin...
# 2       D02                       Starlink Satellite Broadband
# 3       D02          Acoustical Optical Fiber Detection System
# 4       D02                                Tethered UAV System
# ..      ...                                                ...
# 63      D11  Integrating the Wrong Way Detection System int...
# 64      D11                 Imperial County ITS Implementation
# 65      D11               San Vicente Corridor ITS Deployments
# 66      D11       V2X Applications at Signalized Intersections
# 67      D11                             Adaptive ramp metering
#
#                           Project Description (Brief) Project Location  \
# 0   Develop chain-on area winter travel time delay...              N/A
# ...

# %% [markdown]
# # Remove Comments for now since we just need the barebones data to be displayed

# %%
df_copy = df_copy.drop(columns="Comment")

# %%
df_copy
# Out:
#    District                                      Project Title  \
# 0       D02                          Rural Winter Travel Times
# 1       D02  Connected Vehicle Highway Grip Factor Reportin...
# 2       D02                       Starlink Satellite Broadband
# 3       D02          Acoustical Optical Fiber Detection System
# 4       D02                                Tethered UAV System
# ..      ...                                                ...
# 63      D11  Integrating the Wrong Way Detection System int...
# 64      D11                 Imperial County ITS Implementation
# 65      D11               San Vicente Corridor ITS Deployments
# 66      D11       V2X Applications at Signalized Intersections
# 67      D11                             Adaptive ramp metering
#
#                           Project Description (Brief) Project Location  \
# 0   Develop chain-on area winter travel time delay...              NaN
# ...

# %% [markdown]
# # Exporting the df_copy to csv

# %%
df_copy.to_csv("list.csv", index=0)
